# %% [markdown]
# # TP Optimisation II:  A simple neural network
#
# ### Nom(s): Testu
# ### Prénom(s): François
# ### Groupe: B1

# %% [markdown]
# ## Useful packages

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 4
#       2 import random
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.utils import shuffle
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ## Loading of the train and test data

# %%
#
# Load train data
#
Xtrain = np.load('train-images.npy')
Xtrain = np.array([x.ravel()/255 for x in Xtrain])
Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1],1)
Ytrain = np.load('train-labels.npy')
targets_train = []

#
# Convert digits to 10x1 vectors
#
for lab in Ytrain:
    v      = np.zeros((10,1))
    v[lab] = 1
    targets_train+=[np.array(v)]

#
# Load test data
#
Xtest        = np.load('t10k-images.npy')
Xtest        = np.array([x.ravel()/255 for x in Xtest])
Xtest        = Xtest.reshape(Xtest.shape[0],Xtest.shape[1],1)
Ytest        = np.load('t10k-labels.npy')
targets_test = []

#
# Convert digits to 10x1 vectors
#
for lab in Ytest:
    v = np.zeros((10,1))
    v[lab]=1
    targets_test+=[np.array(v)]
#
# Outputs
#
print('There are ',Xtrain.shape[0],'images in the train set')
print('There are ',Xtest.shape[0],'images in the test set')
# Out:
# There are  60000 images in the train set
# There are  10000 images in the test set

# %% [markdown]
# ## Definition of the activation function
#
#  The activation function defines the output of a node given a set of inputs. We use the <a href="https://en.wikipedia.org/wiki/Softmax_function">softmax</a> function defined by
#
#  $$\sigma_{\alpha} : \mathbb{R}^p\rightarrow [0,1]^p, \quad \textrm{ s.t.} \quad[\sigma_{\alpha}(x)]_i=\frac{e^{x_i+\alpha_i}}{\displaystyle{\sum_{j=1}^{p}e^{x_j+\alpha_j}}}\quad \forall i=1:p. $$

# %%
#
# Nonlinear activation function
#
def softmax(x,alpha):
    """
    Softmax unit activation function 
    x    : Numpy array
    alpha: scalar
    """ 
    #
    # TO DO
    num = np.exp(alpha+x)
    den = np.sum(np.exp(alpha+x))
    value = num/den
    #
    
    return value

# %%
#
# Example of a plot of the activation function
#
t     = np.arange(-5,5,0.1)
alpha = 0. #np.arange(-50,50,1)
plt.figure(figsize=(10,10))
plt.plot(t,softmax(t,alpha))
plt.grid(True)
plt.show()

# %% [markdown]
# ## Definition of a simple neural network
#
# We use a one-layer fully-connected neural network with the <a href="https://en.wikipedia.org/wiki/Softmax_function">softmax</a> activation function.

# %%
def NN(x,W):
    """
    # One-layer fully connected neural network
    # x: image, i.e. 784x1 vector (28x28)
    # W: weight matrices of shape 10x784   
    """
    #
    # TO DO: return pred (predicted probabilities) 
    pred = softmax(np.dot(W,x),1)
    #
    
    return pred

# %% [markdown]
# ## Definition of the loss function
#
# The loss function is the <a href="https://en.wikipedia.org/wiki/Cross_entropy">cross-entropy</a> defined by
#
# $J(W)=-\sum_{i=1}^N p_i \log(q_i(W)),$ where $N$ is the number of classes, $(p_i)_{i=1:N}$ are the probabilities of  a data from the training set to belong to a class (0 or 1 because the labels are known), and $(q_i(W))_{i=1:N}$ are the predicted probabilities from the model
#
# $$\forall i=1:N, \quad q_i(W)=[\sigma_{\alpha}(Wx)]_i.$$

# %%
#
# Loss function = Cross-entropy
#
def cross_entropy(pred,target,x):
    """
    pred:   predicted probabilities (q(W))
    target: probabilities (p)
    x:      image 
    """ 
    #
    # TO DO: return ce (cross_entropy)
    #
    ce = -np.sum(target*np.log(pred))
    #
    # gradient of the cross-entropy
    s = pred
    u    =  np.ones((s.shape[0],1))
    g    = (-u.T.dot(target)*(s.dot(x.T))+target*x.T)
    grad = -g.reshape(x.shape[0]*target.shape[0],1)
    
    return ce,grad
#
# Main function 
#
def f(W,x,target):
    """
    W:      weights
    target: probabilities (p)
    x:      image
    """
    #
    # TO DO: return ce, grad, pred (cross_entropy, gradient, predicted probabilities)
    #
    pred = NN(x,W)
    ce,grad = cross_entropy(pred,target,x)
    
    return ce,grad,pred

# %%
#
# Test information on the gradient with calls of f
#

# Define weight matrices
W      = np.random.rand(10,Xtrain.shape[1])
eps    = 1e-8
d      = np.random.rand(10,Xtrain.shape[1])
Wtilde = W+eps*d

# Retrieve the information on the gradients
res    = (f(Wtilde,Xtrain[0],targets_train[0])[0]-f(W,Xtrain[0],targets_train[0])[0])/eps
print(res)

g      = f(W,Xtrain[0],targets_train[0])[1]
print(g.T.dot(d.reshape(7840,1)))
# Out:
# 2.8007501651217126
# [[2.80075053]]

# %% [markdown]
# ## Generating batches

# %%
#
# Function to create batches of samples to be used later in the training phase
#
def create_batches(x,bs):
    """
    x : set to be considered (array)
    bs: batch size (scalar)
    """
    batches = []
    ind     = np.arange(x.shape[0])
    random.shuffle(ind)
    nbatch  = ind.shape[0]//bs
    rest    = ind.shape[0]%bs
    
    for n in range(nbatch):
        batches +=[ind[bs*n:bs*(n+1)]]
    
    # Put the remaining elements in a last batch
    if rest !=0:        
        batches += [ind[-rest:]]
        
    return batches

# %% [markdown]
# ## Training of the neural network

# %%
history    = {}
eta        = 1e-5 # learning rate
momentum   = 0.   # momemtum factor
N_EPOCHS   = 10  
BatchSizes = [10000,1024,256] # try different batch sizes for the analysis

m = Xtrain.shape[1]
for bs in BatchSizes:
    #
    # Sensitivity to the batch size to be investigated in the analysis
    #
    print('batch size=',bs)
    
    history[bs]={'train loss':[],'train acc':[],'test loss':[0], 'test acc':[0]}
    
    # Initialization of the weights
    w = np.random.rand(10,m)
    
    for n in range(N_EPOCHS):
        # Minimization of the loss function
        Batches=create_batches(Xtrain,bs)

        for batch in Batches:
            # Loop on the batches
            # Initialisation
            s_grad = 0
            s_ce = 0
            train_acc = 0
            wtemp = w

            # L'objectif est de moyenner les valeurs de 'train_acc' et de cross_entropy
            # On calcule pour le Xtrain associé à b, son gradient, sa prédiction et sa ce
            grad = np.zeros((10,Xtrain.shape[1]))
            for i in batch:
                x = Xtrain[i]
                targ = targets_train[i]
                ce, gradtemp, pred = f(w,x,targ)
                # On ajoute le gradient et la cross-entropy
                grad += gradtemp.reshape(10,Xtrain.shape[1])
                s_ce += ce
                # On augmente la précision dans le cas où la prédiction est juste
                train_acc += np.argmax(pred)==np.argmax(targets_train[i])

            # On met à jour les valeurs de training
            history[bs]['train loss'] += [s_ce/batch.shape[0]]
            history[bs]['train acc'] += [train_acc/batch.shape[0]]
        
            # La matrice des poids est maj
            # Le but est de faire évoluer le modèle en donnant des poids plus cohérents
            w = w - eta*grad + momentum*(w-wtemp)
                   
        # Test accuracy at the end of each epoch on the training set
        # On teste si les approximations sont bonnes
        test_acc = 0
        test_loss = 0
        for i in range(Xtest.shape[0]):
            xt = Xtest[i]
            pred = NN(xt,w)
            # On augmente la précision dans le cas où la prédiction est juste
            test_acc  += np.argmax(pred)==np.argmax(targets_test[i])
            test_loss += cross_entropy(pred,targets_test[i],Xtest[i])[0]

        # On met à jour les valeurs de test
        history[bs]['test acc']  += [test_acc/Xtest.shape[0]]
        history[bs]['test loss'] += [test_loss/Xtest.shape[0]]

        print('Epoch number :', n+1,'test accuracy:',history[bs]['test acc'][n+1],'test loss',history[bs]['test loss'][n+1])
        

    print('\n')
# Out:
# batch size= 10000
# Epoch number : 1 test accuracy: 0.1948 test loss 3.4434236224280785
# Epoch number : 2 test accuracy: 0.2714 test loss 2.693733019558792
# Epoch number : 3 test accuracy: 0.3458 test loss 2.258522550878832
# Epoch number : 4 test accuracy: 0.4082 test loss 1.9435236153910558
# Epoch number : 5 test accuracy: 0.4665 test loss 1.7076487211609368
# Epoch number : 6 test accuracy: 0.5152 test loss 1.5277461059141606
# Epoch number : 7 test accuracy: 0.5543 test loss 1.387104630160866
# Epoch number : 8 test accuracy: 0.5889 test loss 1.2749875861154418
# Epoch number : 9 test accuracy: 0.6168 test loss 1.1839357940873692
# Epoch number : 10 test accuracy: 0.6406 test loss 1.1087564074640441
#
#
# batch size= 1024
# Epoch number : 1 test accuracy: 0.1822 test loss 2.8937546297913426
# Epoch number : 2 test accuracy: 0.2784 test loss 2.4172204366735763
# Epoch number : 3 test accuracy: 0.3581 test loss 2.0785715780198117
# Epoch number : 4 test accuracy: 0.4241 test loss 1.8267247216379616
# Epoch number : 5 test accuracy: 0.474 test loss 1.634108431556096
# Epoch number : 6 test accuracy: 0.5161 test loss 1.4830988527185949
# Epoch number : 7 test accuracy: 0.5487 test loss 1.3624308253755948
# Epoch number : 8 test accuracy: 0.5788 test loss 1.2642232803622835
# Epoch number : 9 test accuracy: 0.6065 test loss 1.1831440679842826
# Epoch number : 10 test accuracy: 0.6314 test loss 1.1152452902338381
#
#
# batch size= 256
# Epoch number : 1 test accuracy: 0.1278 test loss 3.276170499894456
# Epoch number : 2 test accuracy: 0.206 test loss 2.648632045957633
# Epoch number : 3 test accuracy: 0.3023 test loss 2.2007406170309385
# Epoch number : 4 test accuracy: 0.3936 test loss 1.8762511384976388
# Epoch number : 5 test accuracy: 0.4665 test loss 1.6407376662297946
# Epoch number : 6 test accuracy: 0.5208 test loss 1.466213800583647
# Epoch number : 7 test accuracy: 0.5632 test loss 1.3333257699843164
# Epoch number : 8 test accuracy: 0.5975 test loss 1.2295618927288121
# Epoch number : 9 test accuracy: 0.6208 test loss 1.146008289044518
# Epoch number : 10 test accuracy: 0.643 test loss 1.077316527118811

# %% [markdown]
# ## Plots of the evolution of the loss function

# %%
for bs in BatchSizes:
       
    n_batch = Xtrain.shape[0]//bs     
    if Xtrain.shape[0]%bs!=0:
        n_batch+=1
        
    E  = [n_batch*n for n in np.arange(N_EPOCHS+1)]
    Ep = [str(n) for n in np.arange(N_EPOCHS+1)]
    
    plt.figure(figsize=(7,7))
    plt.plot(history[bs]['train loss'],label = 'training loss')
    plt.plot(E[1:],history[bs]['test loss'][1:],linewidth=2.5,label = 'test loss')
    plt.xticks(E,Ep)
    plt.xlabel('Epochs')
    plt.ylabel('Loss Value')
    #plt.ylim([0,np.max(history[bs]['test loss'])+2])
    plt.grid(True)
    plt.legend()
    plt.title(f'model trained with a Batch size of {bs} samples and learning rate of {eta}')
    plt.show()

# %% [markdown]
# ## Plots of the evolution of the accuracy

# %%
for bs in BatchSizes:
    print(bs)   
    n_batch = Xtrain.shape[0]//bs     
    if Xtrain.shape[0]%bs!=0:
        n_batch+=1
        
    print(n_batch)
    E=[n_batch*n for n in np.arange(N_EPOCHS+1)]
    Ep = [str(n) for n in np.arange(N_EPOCHS+1)]
    
    plt.figure(figsize=(7,7))
    plt.plot(history[bs]['train acc'] ,label  = 'training acuracy')
    plt.plot(E[1:],history[bs]['test acc'][1:],linewidth=2.5,label = 'test acuracy')
    plt.xticks(E,Ep)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.grid(True)
    plt.title(f'model trained with a Batch size of {bs} samples and learning rate of {eta}')
    plt.ylim([0,1])
    plt.legend()
    
    plt.show()
# Out:
# 10000
# 6
# 1024
# 59
# 256
# 235

# %% [markdown]
# ## Analysis of the results
#
# Please provide your comments on the sensitivity of the results to the parameters involved in the learning process (batch size, learning rate, momentum).

# %% [markdown]
# ### Your comments:
